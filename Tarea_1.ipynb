# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo 16

# %% [markdown]
# ## Integrantes:
# * Fernanda Ojeda - 202273025-0
# * Benjamin Reyes - 202273053-6
# * Sebastian Reyes - 202273105-2

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\benja\appdata\local\programs\python\python312\lib\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1
# Out:
# env: DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tarea1',
   password="1234"
)

print(conn)
# Out:
# <connection object at 0x00000246B45B6460; dsn: 'user=postgres password=xxx dbname=tarea1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# DROP TABLE IF EXISTS director CASCADE;
# CREATE TABLE director (
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45),
#     edad INT
# );
# Out:
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# DROP TABLE IF EXISTS actor CASCADE;
# CREATE TABLE actor (
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45),
#     edad INT
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# DROP TABLE IF EXISTS pelicula CASCADE;
# CREATE TABLE pelicula (
#     id_pelicula INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     nombre VARCHAR(45),
#     genero VARCHAR(45),
#     duracion INT,
#     fecha_publicacion DATE,
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# DROP TABLE IF EXISTS actor_participa_en_pelicula CASCADE;
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# DROP TABLE IF EXISTS premio_mejor_director CASCADE;
#
# CREATE TABLE premio_mejor_director (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY ,
#     id_director INT,
#     anio INT,
#     FOREIGN KEY(id_director) REFERENCES director(id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# DROP TABLE IF EXISTS premio_mejor_actor CASCADE;
# CREATE TABLE premio_mejor_actor (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     anio INT,
#     FOREIGN KEY (id_actor) REFERENCES actor(id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# DROP TABLE IF EXISTS premio_mejor_pelicula CASCADE;
#
# CREATE TABLE premio_mejor_pelicula (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     anio INT,
#     FOREIGN KEY(id_pelicula) REFERENCES pelicula(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1984, 'director': 92, 'genero': 'Romance', 'cast': [77, 169, 53, 135, 97], 'mejor pelicula': 'no'}, 2: {'año': 2015, 'director': 37, 'genero': 'Acción', 'cast': [33, 111, 79], 'mejor pelicula': 'no'}, 3: {'año': 1996, 'director': 165, 'genero': 'Drama', 'cast': [97, 28, 90], 'mejor pelicula': 'no'}, 4: {'año': 1998, 'director': 74, 'genero': 'Fantasía', 'cast': [16], 'mejor pelicula': 'no'}, 5: {'año': 2012, 'director': 101, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 6: {'año': 2021, 'director': 184, 'genero': 'Acción', 'cast': [41, 146, 35], 'mejor pelicula': 'no'}, 7: {'año': 2020, 'director': 6, 'genero': 'Ciencia ficción', 'cast': [42], 'mejor pelicula': 'no'}, 8: {'año': 1986, 'director': 106, 'genero': 'Romance', 'cast': [12], 'mejor pelicula': 'no'}, 9: {'año': 1998, 'director': 168, 'genero': 'Comedia', 'cast': [98], 'mejor pelicula': 'no'}, 10: {'año': 1986, 'director': 56, 'genero': 'Fantasía', 'cast': [130, 20, 132], 'mejor pelicula': 'no'}, 11: {'año': 1996, 'director': 119, 'genero': 'Documental', 'cast': [38, 14], 'mejor pelicula': 'no'}, 12: {'año': 1998, 'director': 76, 'genero': 'Musical', 'cast': [52], 'mejor pelicula': 'no'}, 13: {'año': 1970, 'director': 113, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 14: {'año': 1998, 'director': 158, 'genero': 'Musical', 'cast': [82], 'mejor pelicula': 'no'}, 15: {'año': 1975, 'director': 66, 'genero': 'Ciencia ficción', 'cast': [90, 111], 'mejor pelicula': 'no'}, 16: {'año': 1977, 'director': 92, 'genero': 'Musical', 'cast': [171, 99, 31, 138], 'mejor pelicula': 'no'}, 17: {'año': 1983, 'director': 153, 'genero': 'Misterio', 'cast': [42], 'mejor pelicula': 'no'}, 18: {'año': 1971, 'director': 109, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 19: {'año': 1995, 'director': 102, 'genero': 'Drama', 'cast': [46], 'mejor pelicula': 'no'}, 20: {'año': 2002, 'director': 112, 'genero': 'Ciencia ficción', 'cast': [145], 'mejor pelicula': 'no'}, 21: {'año': 1985, 'director': 111, 'genero': 'Acción', 'cast': [91, 161], 'mejor pelicula': 'no'}, 22: {'año': 2001, 'director': 117, 'genero': 'Comedia', 'cast': [139, 100], 'mejor pelicula': 'no'}, 23: {'año': 1985, 'director': 172, 'genero': 'Drama', 'cast': [109, 116, 190, 106], 'mejor pelicula': 'no'}, 24: {'año': 2005, 'director': 145, 'genero': 'Comedia', 'cast': [3, 2], 'mejor pelicula': 'no'}, 25: {'año': 1961, 'director': 83, 'genero': 'Documental', 'cast': [176, 118, 147], 'mejor pelicula': 'no'}, 26: {'año': 2001, 'director': 145, 'genero': 'Western', 'cast': [54, 186, 191, 143], 'mejor pelicula': 'no'}, 27: {'año': 1970, 'director': 181, 'genero': 'Romance', 'cast': [112, 21], 'mejor pelicula': 'no'}, 28: {'año': 2018, 'director': 3, 'genero': 'Fantasía', 'cast': [200, 81, 181, 149, 29, 150], 'mejor pelicula': 'no'}, 29: {'año': 2016, 'director': 36, 'genero': 'Documental', 'cast': [155], 'mejor pelicula': 'no'}, 30: {'año': 1961, 'director': 132, 'genero': 'Acción', 'cast': [], 'mejor pelicula': 'no'}, 31: {'año': 1999, 'director': 181, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 32: {'año': 1966, 'director': 75, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 33: {'año': 1961, 'director': 113, 'genero': 'Drama', 'cast': [43, 145, 71], 'mejor pelicula': 'no'}, 34: {'año': 1964, 'director': 160, 'genero': 'Ciencia ficción', 'cast': [], 'mejor pelicula': 'no'}, 35: {'año': 1998, 'director': 19, 'genero': 'Western', 'cast': [74], 'mejor pelicula': 'no'}, 36: {'año': 1967, 'director': 173, 'genero': 'Aventura', 'cast': [167], 'mejor pelicula': 'no'}, 37: {'año': 2014, 'director': 170, 'genero': 'Misterio', 'cast': [42, 24], 'mejor pelicula': 'no'}, 38: {'año': 2012, 'director': 70, 'genero': 'Animación', 'cast': [], 'mejor pelicula': 'no'}, 39: {'año': 1995, 'director': 45, 'genero': 'Romance', 'cast': [63, 167], 'mejor pelicula': 'no'}, 40: {'año': 2017, 'director': 178, 'genero': 'Acción', 'cast': [194, 112], 'mejor pelicula': 'no'}, 41: {'año': 1 ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre
# FROM pelicula
# WHERE fecha_publicacion > CURRENT_DATE - INTERVAL '1 year';
#
# #Esta consulta selecciona el nombre de las película de la tabla 'pelicula' ,
# #luego busca la fecha de publicación; para ver si cumple con el requisito, utiliza la fecha actual y le resta un año a esa fecha.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 1 rows affected.
# [('La maldición de el sapo',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre, fecha_publicacion
# FROM pelicula
# WHERE genero = 'Drama'
# AND EXTRACT(YEAR FROM fecha_publicacion) = 2023;
#
# #Esta consulta selecciona el nombre y la fecha de publicación de la tabla pelicula, luego busca que el genero sea drama,
# #que es el cual requerimos, seguidamente compara la fecha de publicacion con el año 2023.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT DISTINCT actor.nombre
# FROM actor
# JOIN actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# WHERE pelicula.genero = 'Comedia';
#
#
# # Esta consulta selecciona los nombres de los actores que participaron en películas de género "Comedia".
# # Para ello, realiza una serie de uniones entre las tablas 'actor', 'actor_participa_en_pelicula' y 'pelicula',
# # y luego filtra las películas que pertenecen al género 'Comedia'.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 47 rows affected.
# [('Darya Lima',),
#  ('Quintus Teles',),
#  ('Irina Wu',),
#  ('Mehmet Zapata',),
#  ('Katarina Janssen',),
#  ('Mehmet Oliveira',),
#  ('Mehmet Zhang',),
#  ('Qiu Rodriguez',),
#  ('Xin Rodriguez',),
#  ('Umar Oliveira',),
#  ('Tatiana Lopes',),
#  ('Xavier Olivares',),
#  ('Ximena Hernandez',),
#  ('Fatemeh Santana',),
#  ('Zafar Olivares',),
#  ('Sakura Dutta',),
#  ('Abdullah Olivares',),
#  ('Orhan Joaquim',),
#  ('Alessandro Nunes',),
#  ('Bianca Fernandes',),
#  ('Hiroko Janssen',),
#  ('Valentina Gao',),
#  ('Yasmin Queiroz',),
#  ('Irina Oliveira',),
#  ('Javier Nguyen',),
#  ('Tatiana Duarte',),
#  ('Elif Nunes',),
#  ('Quentin Carvalho',),
#  ('Orhan Qian',),
#  ('Wilhelmina Gao',),
#  ('Xin Jimenez',),
#  ('Quentin Cruz',),
#  ('Valentina Zambrano',),
#  ('Hanako Gomes',),
#  ('Mehmet Santana',),
#  ('Qiu Borges',),
#  ('Oscar Pereira',),
#  ('Rosa Duarte',),
#  ('Fatemeh Xia',),
#  ('Pilar Alvarez',),
#  ('Emiko Yan',),
#  ('Bianca Zambrano',),
#  ('Ilya Ramos',),
#  ('Han Sousa',),
#  ('Emiko Olivares',),
#  ('Genghis Cruz',),
#  ('Abdullah Martinez',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT p.genero, COUNT(pp.id_premio) as cantidad_premios
# FROM pelicula p
# JOIN premio_mejor_pelicula pp ON p.id_pelicula = pp.id_pelicula
# GROUP BY p.genero
# ORDER BY cantidad_premios DESC;
#
# # Esta consulta selecciona el género de las películas y cuenta la cantidad de premios obtenidos por cada género.
# # Para ello, realiza una unión entre las tablas 'pelicula' y 'premio_mejor_pelicula' utilizando el ID de la película.
# # Luego agrupa los resultados por género y cuenta la cantidad de premios para cada género.
# # Finalmente, ordena los resultados en orden descendente según la cantidad de premios.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 14 rows affected.
# [('Musical', 4),
#  ('Animación', 3),
#  ('Fantasía', 3),
#  ('Terror', 3),
#  ('Acción', 3),
#  ('Comedia', 3),
#  ('Aventura', 2),
#  ('Misterio', 2),
#  ('Drama', 2),
#  ('Suspense', 2),
#  ('Documental', 1),
#  ('Ciencia ficción', 1),
#  ('Romance', 1),
#  ('Western', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT pelicula.nombre, COUNT(actor_participa_en_pelicula.id_actor) AS cantidad_actores
# FROM pelicula
# JOIN actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# GROUP BY pelicula.id_pelicula, pelicula.nombre
# HAVING COUNT(actor_participa_en_pelicula.id_actor) >= 2
# ORDER BY cantidad_actores DESC;
#
# # Esta consulta selecciona el nombre de las películas y cuenta la cantidad de actores que participaron en cada una.
# # Para ello, realiza una unión entre las tablas 'pelicula' y 'actor_participa_en_pelicula' utilizando el ID de la película.
# # Luego, agrupa los resultados por el ID y el nombre de la película.
# # Posteriormente, filtra los resultados para incluir solo aquellas películas que tienen al menos dos actores.
# # Finalmente, ordena los resultados en orden descendente según la cantidad de actores.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 146 rows affected.
# [('La senda de la esperanza', 6),
#  ('La misión de la magia', 6),
#  ('El castillo de el río', 6),
#  ('El cuento de hadas de el enigma', 6),
#  ('El guardián de la prisión', 5),
#  ('Las aventuras de el laberinto', 5),
#  ('El castillo de la noche', 5),
#  ('El arco iris de el enigma', 5),
#  ('La búsqueda del tesoro de el laberinto', 5),
#  ('El espejismo de el muro', 5),
#  ('La búsqueda del tesoro de la guerra', 4),
#  ('El canto de sirena de la resistencia', 4),
#  ('La búsqueda del tesoro de la bailarina', 4),
#  ('El hechizo de la montaña', 4),
#  ('La tormenta de la bailarina', 4),
#  ('La canción de la espada', 4),
#  ('El cuento de hadas de la montaña', 4),
#  ('La trampa de la amistad', 4),
#  ('El espejismo de la traición', 4),
#  ('El vuelo mágico de la montaña', 4),
#  ('La llave de el guerrero', 4),
#  ('La redención de la bailarina', 4),
#  ('El misterio de la verdad', 4),
#  ('El tesoro escondido de el enigma', 4),
#  ('El eclipse de la pesadilla', 4),
#  ('La senda de la escuela', 3),
#  ('La conquista de la traición', 3),
#  ('El secreto de la bruja', 3),
#  ('La fuga de la trampa', 3),
#  ('La cripta de la magia', 3),
#  ('El eclipse de el laberinto', 3),
#  ('La metamorfosis de el viaje', 3),
#  ('El descubrimiento de el mito', 3),
#  ('La escalada de la luz', 3),
#  ('El laberinto de la prisión', 3),
#  ('La maldición del vampiro de el perdón', 3),
#  ('El ritual de la caída', 3),
#  ('El vuelo de la isla', 3),
#  ('El último viaje de la estrella', 3),
#  ('La estirpe de la selva', 3),
#  ('El lamento de la sonrisa', 3),
#  ('La escalada de la leyenda', 3),
#  ('La batalla de el fuego', 3),
#  ('La travesía del océano de la gárgola', 3),
#  ('El secreto de la paz', 3),
#  ('El pacto de la nube', 3),
#  ('La doncella de el renacer', 3),
#  ('El eclipse de el rey', 3),
#  ('El eclipse de la caverna', 3),
#  ('La odisea de la estrella', 3),
#  ('La travesía sin retorno de el monstruo', 3),
#  ('El secreto de la muralla', 3),
#  ('Las aventuras de el muro', 3),
#  ('La canción de el misterio', 3),
#  ('El descubrimiento de el destino', 3),
#  ('El regreso de la luna', 3),
#  ('El regreso de la aventura', 3),
#  ('La metamorfosis de el guerrero', 3),
#  ('La travesura de el viaje', 3),
#  ('El camino hacia el laberinto', 3),
#  ('El secreto de el lamento', 3),
#  ('La travesura de el sueño', 3),
#  ('El pacto de la despedida', 3),
#  ('La tormenta de la montaña', 3),
#  ('La trampa de la puerta', 3),
#  ('El hechizo de la montaña', 3),
#  ('La travesía de el descubrimiento', 3),
#  ('El lamento de la aventura', 3),
#  ('El guardián de la expedición', 3),
#  ('El descubrimiento de la paz', 3),
#  ('La llave de la paz', 3),
#  ('La estirpe de la libertad', 2),
#  ('El ritual de la aventura', 2),
#  ('La fuente de el renacimiento', 2),
#  ('El tesoro de el león', 2),
#  ('La travesía de la pesadilla', 2),
#  ('La resurrección de el mar', 2),
#  ('La cripta de la esperanza', 2),
#  ('El ritual de la luz', 2),
#  ('La invasión de la perdición', 2),
#  ('La maldición de el sapo', 2),
#  ('La llave de la cueva', 2),
#  ('El grito de el horizonte', 2),
#  ('El refugio de la espada mágica', 2),
#  ('El caballero de el tesoro', 2),
#  ('La llave de el viajero', 2),
#  ('El regreso de la verdad', 2),
#  ('El descubrimiento de la pasión', 2),
#  ('El despertar de el muro', 2),
#  ('La estrella fugaz de el fuego', 2),
#  ('La búsqueda del tesoro de la tormenta', 2),
#  ('El resurgimiento de la cueva', 2),
#  ('El despertar de la ley', 2),
#  ('La leyenda de el sueño', 2),
#  ('La cripta de el león', 2),
#  ('El canto de sirena de el sueño', 2),
#  ('La fuente de el grito', 2),
#  ('La búsqueda del tesoro de la travesía', 2),
#  ('El despertar de la huida', 2),
#  ('El enigma de el renacer', 2),
#  ('El amanecer de la promesa', 2),
#  ('La fuga de el explorador', 2),
#  ('El enigma de la montaña', 2),
#  ('El secreto oscuro de el trono', 2),
#  ('El viaje de el faro', 2),
#  ('El regreso de la cascada', 2),
#  ('La batalla de el unicornio', 2),
#  ('El ritual de la libertad', 2),
#  ('La invasión de la isla', 2),
#  ('La llave de la tierra', 2),
#  ('El caballero de la caída', 2),
#  ('El resurgimiento de la senda', 2),
#  ('El guardián de la puerta', 2),
#  ('La travesura de la clave', 2),
#  ('El vuelo de el viaje', 2),
#  ('La estrella fugaz de la aventura', 2),
#  ('La danza de la expedición', 2),
#  ('El camino hacia la traición', 2),
#  ('La escalada de la cascada', 2),
#  ('La búsqueda de la caída', 2),
#  ('La travesura de el fuego', 2),
#  ('El hechizo de la princesa', 2),
#  ('La cripta de el desafío', 2),
#  ('La resurrección de la corona', 2),
#  ('La fuga de el secreto', 2),
#  ('El amanecer de la gárgola', 2),
#  ('El bosque encantado de la pesadilla', 2),
#  ('La llegada de la perdición', 2),
#  ('La travesía del océano de el secreto', 2),
#  ('El tesoro de la luz', 2),
#  ('El tesoro escondido de el puente', 2),
#  ('La trampa de la sombra', 2),
#  ('El amanecer de la leyenda', 2),
#  ('El renacimiento de el explorador', 2),
#  ('La travesía sin retorno de la mariposa', 2),
#  ('La senda de la bailarina', 2),
#  ('El destino de la luz', 2),
#  ('La tormenta de el océano', 2),
#  ('La rebelión de la oscuridad', 2),
#  ('El espejismo de el laberinto', 2),
#  ('El canto de sirena de el abismo', 2),
#  ('La búsqueda del tesoro de la reina', 2),
#  ('La odisea de el sueño', 2),
#  ('La trampa de la revelación', 2),
#  ('La tormenta de la revelación', 2),
#  ('La travesía del océano de el renacer', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH AgeDifferences AS (
#     SELECT
#         p.id_pelicula,
#         p.nombre AS NombrePelicula,
#         MAX(a.edad) - MIN(a.edad) AS BrechaEdad,
#         MAX(a.edad) AS EdadMaxima,
#         MIN(a.edad) AS EdadMinima
#     FROM
#         pelicula p
#         JOIN actor_participa_en_pelicula ape ON p.id_pelicula = ape.id_pelicula
#         JOIN actor a ON ape.id_actor = a.id_actor
#     GROUP BY
#         p.id_pelicula
# ),
# RankedMovies AS (
#     SELECT
#         NombrePelicula,
#         EdadMinima,
#         EdadMaxima,
#         BrechaEdad,
#         RANK() OVER (ORDER BY BrechaEdad DESC) AS Rank
#     FROM
#         AgeDifferences
# )
# SELECT
#     NombrePelicula AS "Nombre",
#     EdadMinima AS "Edad del actor más joven",
#     EdadMaxima AS "Edad del actor más viejo"
# FROM
#     RankedMovies
# WHERE
#     Rank = 1;
#
# # Esta consulta calcula la brecha de edad entre el actor más joven y el más viejo para cada película.
# # Luego, clasifica las películas en orden descendente según la brecha de edad y selecciona la película con la mayor brecha de edad.
# # Devuelve el nombre de la película junto con las edades del actor más joven y del más viejo en esa película.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 1 rows affected.
# [('La búsqueda del tesoro de el laberinto', 17, 70)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH LongestMovie AS (
#     SELECT id_pelicula
#     FROM pelicula
#     ORDER BY duracion DESC
#     LIMIT 1
# ),
# MovieAwards AS (
#     SELECT premio_mejor_pelicula.anio
#     FROM premio_mejor_pelicula
#     JOIN LongestMovie ON premio_mejor_pelicula.id_pelicula = LongestMovie.id_pelicula
# )
# SELECT anio AS "Año"
# FROM MovieAwards;
#
#
#
# # Primero utiliza una subconsulta para encontrar la película más larga en términos de duración.
# # Luego, otra subconsulta se une a la tabla de premios para encontrar el año en que esta película específica recibió un premio.
# # Finalmente, la consulta principal selecciona el año de estos premios y los muestra como "Año".
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre AS "Nombre del actor",
#     COUNT(DISTINCT pelicula.id_director) AS "Cantidad de directores",
#     MAX(pelicula.nombre) AS "Nombre de una película"
# FROM
#     actor
# JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# GROUP BY
#     actor.id_actor, actor.nombre
# HAVING
#     COUNT(DISTINCT pelicula.id_director) > 1
# ORDER BY
#     "Cantidad de directores" DESC, "Nombre del actor";
#
#
# # Se etiqueta los datos
# # Para ello, realiza una serie de uniones entre las tablas 'actor', 'actor_participa_en_pelicula' y 'pelicula' utilizando los IDs correspondientes.
# # Luego, agrupa los resultados por el ID del actor y su nombre.
# # Posteriormente, filtra los resultados para incluir solo aquellos actores que han trabajado con más de un director diferente.
# # Finalmente, ordena los resultados primero por la cantidad de directores en orden descendente y luego por el nombre del actor.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 147 rows affected.
# [('Natalia Teles', 8, 'Las aventuras de el puente'),
#  ('Elena Goncalves', 7, 'La travesura de la guerra'),
#  ('Natalia Sousa', 7, 'La travesía del océano de la isla'),
#  ('Hanako Urbina', 6, 'La senda de la escuela'),
#  ('Ilya Watanabe', 6, 'La trampa de la amistad'),
#  ('Orhan Joaquim', 6, 'La sombra de el mito'),
#  ('Rosa Pacheco', 6, 'La travesía sin retorno de el monstruo'),
#  ('Abdullah Mendes', 5, 'La odisea de la estrella'),
#  ('Abdullah Olivares', 5, 'La travesura de el sueño'),
#  ('Akira Mendes', 5, 'La travesía del océano de la gárgola'),
#  ('Alessandro Nunes', 5, 'La batalla de el unicornio'),
#  ('Bianca Zambrano', 5, 'El último viaje de la estrella'),
#  ('Chidike Petrov', 5, 'Las aventuras de el laberinto'),
#  ('Ilya Ramos', 5, 'La travesura de el viaje'),
#  ('Katarina Janssen', 5, 'La travesía del océano de la estrella fugaz'),
#  ('Mehmet Zhang', 5, 'El vuelo de la misión'),
#  ('Natalia Dutta', 5, 'La estirpe de el unicornio'),
#  ('Xavier Olivares', 5, 'La trampa de la amistad'),
#  ('Yasmin Queiroz', 5, 'La leyenda de el sueño'),
#  ('Bianca Fernandes', 4, 'Las aventuras de el muro'),
#  ('Chiyoko Estevez', 4, 'El secreto de la paz'),
#  ('Elena Pereira', 4, 'La redención de la bailarina'),
#  ('Emiko Olivares', 4, 'La trampa de la pesadilla'),
#  ('Emiko Pereira', 4, 'La travesía de la pesadilla'),
#  ('Genghis Urbina', 4, 'La escalada de la leyenda'),
#  ('Hiroko Pereira', 4, 'La trampa de la sombra'),
#  ('Irina Carvalho', 4, 'La resurrección de la corona'),
#  ('Irina Oliveira', 4, 'La danza de la expedición'),
#  ('Javier Rodriguez', 4, 'La misión de la magia'),
#  ('Jin Lopez', 4, 'La travesura de el sueño'),
#  ('Katarina Xia', 4, 'La senda de la reina'),
#  ('Khaled Yamamoto', 4, 'La senda de la salvación'),
#  ('Mehmet Correia', 4, 'La venganza de el susurro'),
#  ('Mehmet Oliveira', 4, 'La leyenda perdida de la traición'),
#  ('Mehmet Zapata', 4, 'La tormenta de la montaña'),
#  ('Orhan Dutta', 4, 'La travesura de la clave'),
#  ('Sakura Petrov', 4, 'La llegada de la espada mágica'),
#  ('Valentina Hidalgo', 4, 'La travesía sin retorno de el monstruo'),
#  ('Wang Ferreira', 4, 'La llegada de el renacer'),
#  ('Wang Yan', 4, 'La tormenta de la bailarina'),
#  ('Wilhelmina Gao', 4, 'La travesía sin retorno de la mariposa'),
#  ('Xin Rodriguez', 4, 'La búsqueda del tesoro de el laberinto'),
#  ('Yuri Iglesias', 4, 'La metamorfosis de el viaje'),
#  ('Yusef Urbina', 4, 'La odisea de la estrella'),
#  ('Zafar Gao', 4, 'La travesía del océano de el secreto'),
#  ('Bianca Tan', 3, 'La invasión de la academia'),
#  ('Chen Ueno', 3, 'La travesura de el sueño'),
#  ('Darya Lima', 3, 'El tesoro de la luz'),
#  ('Elena Wu', 3, 'El prisionero de el laberinto'),
#  ('Elif Nunes', 3, 'La redención de la bailarina'),
#  ('Emiko Yan', 3, 'La trampa de la amistad'),
#  ('Fabiana Diniz', 3, 'La misión de la magia'),
#  ('Fabiana Queiroz', 3, 'Las aventuras de el muro'),
#  ('Fabiana Velez', 3, 'La tormenta de la bailarina'),
#  ('Fadhila Ferreira', 3, 'La travesura de la clave'),
#  ('Genghis Mendes', 3, 'El vuelo de la isla'),
#  ('Genghis Zhang', 3, 'La misión de la magia'),
#  ('Hiroko Janssen', 3, 'La tormenta de la montaña'),
#  ('Irina Wu', 3, 'La llave de el guerrero'),
#  ('Leonardo Henriquez', 3, 'La travesía del océano de la profecía'),
#  ('Leticia Correia', 3, 'El guardián de la expedición'),
#  ('Leticia Joaquim', 3, 'La búsqueda del tesoro de la guerra'),
#  ('Mehmet Iglesias', 3, 'Las aventuras de la esperanza'),
#  ('Nina Watanabe', 3, 'La trampa de la puerta'),
#  ('Orhan Inácio', 3, 'La batalla de el fuego'),
#  ('Orhan Qian', 3, 'La rebelión de la oscuridad'),
#  ('Oscar Pereira', 3, 'La travesía del océano de el renacer'),
#  ('Parvati Iglesias', 3, 'La invasión de la isla'),
#  ('Parvati Ortega', 3, 'La batalla de el abismo'),
#  ('Pilar Alvarez', 3, 'La conquista de la traición'),
#  ('Pilar Estevez', 3, 'Las aventuras de el muro'),
#  ('Qiu Borges', 3, 'El vuelo de el viaje'),
#  ('Quentin Carvalho', 3, 'La cripta de la esperanza'),
#  ('Quentin Cruz', 3, 'La travesura de el viaje'),
#  ('Quentin Xu', 3, 'La leyenda de el sueño'),
#  ('Rania Ivanov', 3, 'La travesía de el descubrimiento'),
#  ('Rosa Jimenez', 3, 'La búsqueda del tesoro de el laberinto'),
#  ('Rosa Mendes', 3, 'La senda de la escuela'),
#  ('Sakura Dutta', 3, 'La estirpe de la libertad'),
#  ('Tatiana Duarte', 3, 'La resurrección de la batalla'),
#  ('Tatjana Queiroz', 3, 'La metamorfosis de el viaje'),
#  ('Valentina Gao', 3, 'La redención de la bailarina'),
#  ('Ximena Iglesias', 3, 'La fuga de la pesadilla'),
#  ('Ximena Queiroz', 3, 'La senda de la bailarina'),
#  ('Xin Borges', 3, 'La fuga de el explorador'),
#  ('Yasmin Correia', 3, 'La travesía del océano de la gárgola'),
#  ('Yusef Hidalgo', 3, 'La travesía del océano de la gárgola'),
#  ('Zafar Olivares', 3, 'El tesoro de el león'),
#  ('Zara Pereira', 3, 'La travesura de el fuego'),
#  ('Aarav Ortega', 2, 'La estrella fugaz de la aventura'),
#  ('Abdullah Martinez', 2, 'El ritual de la luz'),
#  ('Beatriz Martinez', 2, 'El tesoro escondido de el enigma'),
#  ('Chiyoko Ivanov', 2, 'La llegada de el destino'),
#  ('Darius Xavier', 2, 'La travesía de la pesadilla'),
#  ('Darya Cruz', 2, 'La resurrección de el sacrificio'),
#  ('Darya Martinez', 2, 'La doncella de la bailarina'),
#  ('Darya Nogueira', 2, 'La escalada de la luz'),
#  ('Elif Joaquim', 2, 'La invasión de el descubrimiento'),
#  ('Elif Vargas', 2, 'La travesura de el peligro'),
#  ('Elif Xavier', 2, 'La senda de la bailarina'),
#  ('Emiko Xu', 2, 'El guardián de la prisión'),
#  ('Fabiana Jimenez', 2, 'La misión de la bruja'),
#  ('Fadhila Gao', 2, 'La canción de el misterio'),
#  ('Fadhila Oliveira', 2, 'La metamorfosis de el guerrero'),
#  ('Fadhila Ramos', 2, 'La llave de la paz'),
#  ('Fatemeh Jimenez', 2, 'La senda de la esperanza'),
#  ('Fatemeh Xia', 2, 'La llave de el guerrero'),
#  ('Genghis Cruz', 2, 'La búsqueda del tesoro de la tormenta'),
#  ('Genghis Montenegro', 2, 'El regreso de la verdad'),
#  ('Giovanni Borges', 2, 'La trampa de la revelación'),
#  ('Giovanni Goncalves', 2, 'La trampa de la magia'),
#  ('Giovanni Nunes', 2, 'La senda de la esperanza'),
#  ('Giovanni Zapata', 2, 'La fuente de el grito'),
#  ('Han Sousa', 2, 'La llave de la cueva'),
#  ('Hanako Alvarez', 2, 'El secreto de la paz'),
#  ('Hanako Gomes', 2, 'La conquista de la traición'),
#  ('Ilya Lopes', 2, 'La travesura de el ángel'),
#  ('Isa Kawaguchi', 2, 'La tormenta de el océano'),
#  ('Jasmin Yamamoto', 2, 'La leyenda perdida de la traición'),
#  ('Javier Alvarez', 2, 'La senda de la esperanza'),
#  ('Javier Nguyen', 2, 'La fuga de el secreto'),
#  ('Katarina Esteves', 2, 'La redención de el vuelo'),
#  ('Leonardo Zapata', 2, 'La invasión de la perdición'),
#  ('Leonardo Zhang', 2, 'El hechizo de la montaña'),
#  ('Leticia Hidalgo', 2, 'La canción de el misterio'),
#  ('Oscar Teles', 2, 'El caballero de la caída'),
#  ('Parvati Ueno', 2, 'La resurrección de la estrella'),
#  ('Qiu Rodriguez', 2, 'La estrella fugaz de el fuego'),
#  ('Quentin Santos', 2, 'La senda de el sacrificio'),
#  ('Quintus Teles', 2, 'El último viaje de la estrella'),
#  ('Rashid Kawaguchi', 2, 'La travesía sin retorno de la mariposa'),
#  ('Sakura Figueiredo', 2, 'La fuente de el renacimiento'),
#  ('Tatiana Lopes', 2, 'La llave de el guerrero'),
#  ('Umar Oliveira', 2, 'La maldición del vampiro de el perdón'),
#  ('Umar Vargas', 2, 'Las aventuras de el laberinto'),
#  ('Ursula Lima', 2, 'Las aventuras de el laberinto'),
#  ('Valentina Zambrano', 2, 'El viaje de el faro'),
#  ('Valeria Cruz', 2, 'La llave de la tierra'),
#  ('Wilhelmina Figueiredo', 2, 'La trampa de la sombra'),
#  ('Xavier Xia', 2, 'Las aventuras de el laberinto'),
#  ('Ximena Hernandez', 2, 'El castillo de el río'),
#  ('Ximena Jimenez', 2, 'La travesía sin retorno de el monstruo'),
#  ('Ximena Jimenez', 2, 'La búsqueda del tesoro de el laberinto'),
#  ('Ximena Tan', 2, 'La travesía de el descubrimiento'),
#  ('Xin Jimenez', 2, 'La tormenta de la revelación'),
#  ('Zafar Lopez', 2, 'La escalada de la luz'),
#  ('Zara Gao', 2, 'La invasión de la esperanza')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre
# FROM
#     actor
# JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# GROUP BY
#     actor.id_actor, actor.nombre
# HAVING
#     BOOL_AND(pelicula.id_director = 1);
#
# # Busca el nombre del actor de la tabla "actor"
# # Se unen las tablas 'actor', 'actor_participa_en_pelicula' y 'pelicula' para obtener la información requerida.
# # Los resultados se agrupan por el ID del actor y su nombre.
# # Se utiliza la función BOOL_AND para verificar si todas las películas en las que ha participado el actor tienen al director con ID 1.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     a.nombre AS "Nombre del actor",
#     p.nombre AS "Nombre de la película",
#     d.nombre AS "Nombre del director",
#     sub_director.total_peliculas AS "Número de películas del director",
#     sub_director.total_premios AS "Número de premios del director"
# FROM
#     actor a
# JOIN
#     actor_participa_en_pelicula ape ON a.id_actor = ape.id_actor
# JOIN
#     pelicula p ON ape.id_pelicula = p.id_pelicula
# JOIN
#     director d ON p.id_director = d.id_director
# LEFT JOIN
#     premio_mejor_actor pma ON a.id_actor = pma.id_actor
# LEFT JOIN
#     (SELECT
#         pelicula.id_director,
#         COUNT(pelicula.id_pelicula) AS total_peliculas,
#         SUM(CASE WHEN pp.id_premio IS NOT NULL THEN 1 ELSE 0 END) AS total_premios
#      FROM
#         pelicula
#      LEFT JOIN
#         premio_mejor_pelicula pp ON pelicula.id_pelicula = pp.id_pelicula
#      GROUP BY
#         pelicula.id_director
#     ) sub_director ON d.id_director = sub_director.id_director
# WHERE
#     pma.id_premio IS NULL
# GROUP BY
#     a.nombre, p.nombre, d.nombre, sub_director.total_peliculas, sub_director.total_premios;
#
#
#
# # Se etiqueta los datos
# # Se unen varias tablas: actor, actor_participa_en_pelicula, pelicula, director, premio_mejor_actor y premio_mejor_pelicula para obtener la información requerida.
# # Se utiliza una subconsulta para calcular el número total de películas y premios dirigidos por cada director.
# # Se filtran los resultados para incluir solo aquellos actores que no han ganado premios como mejor actor.
# # Finalmente, se agrupan los resultados por el nombre del actor, el nombre de la película, el nombre del director, el número total de películas del director y el número total de premios del director.
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 415 rows affected.
# [('Aarav Ortega', 'La canción de la espada', 'Zoya Joaquim', 3, 0),
#  ('Aarav Ortega', 'La estrella fugaz de la aventura', 'Kamala Lima', 2, 0),
#  ('Abdullah Martinez', 'El renacimiento de el explorador', 'Genghis Yan', 4, 0),
#  ('Abdullah Martinez', 'El ritual de la luz', 'Omar Santos', 1, 0),
#  ('Abdullah Mendes', 'El tesoro de la luz', 'Zafar Watanabe', 1, 0),
#  ('Abdullah Mendes', 'La batalla de el misterio', 'Javier Abadi', 2, 1),
#  ('Abdullah Mendes', 'La invasión de la isla', 'Javier Fernandes', 4, 0),
#  ('Abdullah Mendes', 'La misión de el atardecer', 'Rosa Henriquez', 3, 0),
#  ('Abdullah Mendes', 'La misión de la aldea', 'Khaled Watanabe', 2, 0),
#  ('Abdullah Mendes', 'La odisea de la estrella', 'Javier Fernandes', 4, 0),
#  ('Abdullah Olivares', 'El amanecer de la leyenda', 'Akira Dutta', 1, 0),
#  ('Abdullah Olivares', 'El cuento de hadas de el enigma', 'Bianca Abadi', 1, 0),
#  ('Abdullah Olivares', 'El secreto de la muralla', 'Oscar Yilmaz', 3, 0),
#  ('Abdullah Olivares', 'La búsqueda del tesoro de la tormenta', 'Irina Vargas', 4, 0),
#  ('Abdullah Olivares', 'La travesura de el sueño', 'Elena Iglesias', 2, 1),
#  ('Alessandro Nunes', 'El guardián de la prisión', 'Khaled Watanabe', 2, 0),
#  ('Alessandro Nunes', 'El hechizo de el descubrimiento', 'Salim Alvarez', 3, 0),
#  ('Alessandro Nunes', 'El secreto de la bruja', 'Gustavo Uchoa', 1, 1),
#  ('Alessandro Nunes', 'El secreto de la muralla', 'Oscar Yilmaz', 3, 0),
#  ('Alessandro Nunes', 'La batalla de el unicornio', 'Han Hernandez', 5, 1),
#  ('Beatriz Martinez', 'El laberinto de el sol', 'Orhan Wu', 5, 0),
#  ('Beatriz Martinez', 'El tesoro escondido de el enigma', 'Umar Rodriguez', 2, 0),
#  ('Bianca Fernandes', 'El castillo de el río', 'Jasmin Iglesias', 2, 0),
#  ('Bianca Fernandes', 'La escalada de la leyenda', 'Mehmet Wu', 1, 0),
#  ('Bianca Fernandes', 'La trampa de la puerta', 'Quintus Diniz', 2, 0),
#  ('Bianca Fernandes', 'Las aventuras de el muro', 'Pilar Pereira', 1, 1),
#  ('Bianca Jimenez', 'La tormenta de la bailarina', 'Oscar Yilmaz', 3, 0),
#  ('Bianca Olivares', 'El castillo de la noche', 'Hanako Santos', 2, 0),
#  ('Bianca Tan', 'El cuento de hadas de la montaña', 'Salim Velez', 2, 0),
#  ('Bianca Tan', 'La doncella de el renacer', 'Darius Joaquim', 3, 2),
#  ('Bianca Tan', 'La invasión de la academia', 'Vivek Olivares', 1, 0),
#  ('Bianca Zambrano', 'El castillo de la noche', 'Hanako Santos', 2, 0),
#  ('Bianca Zambrano', 'El cuento de hadas de la montaña', 'Salim Velez', 2, 0),
#  ('Bianca Zambrano', 'El descubrimiento de el destino', 'Ursula Xia', 1, 1),
#  ('Bianca Zambrano', 'El eclipse de la caverna', 'Irina Vargas', 4, 0),
#  ('Bianca Zambrano', 'El último viaje de la estrella', 'Mikhail Inácio', 2, 1),
#  ('Chidike Petrov', 'La metamorfosis de la aldea', 'Mikhail Urbina', 1, 0),
#  ('Chidike Petrov', 'La rebelión de la montaña', 'Jasmin Goncalves', 3, 1),
#  ('Chidike Petrov', 'La travesía de el descubrimiento', 'Salim Alvarez', 3, 0),
#  ('Chidike Petrov', 'La travesura de el viaje', 'Emiko Fernandes', 1, 0),
#  ('Chidike Petrov', 'Las aventuras de el laberinto', 'Wilhelmina Ivanov', 2, 1),
#  ('Chiyoko Estevez', 'El descubrimiento de el mito', 'Vivek Joaquim', 1, 0),
#  ('Chiyoko Estevez', 'El hechizo de la montaña', 'Salim Mendes', 2, 0),
#  ('Chiyoko Estevez', 'El misterio de la verdad', 'Javier Teixeira', 1, 0),
#  ('Chiyoko Estevez', 'El secreto de la paz', 'Wilhelmina Rocha', 4, 1),
#  ('Chiyoko Ivanov', 'La fortuna de la corona', 'Tatjana Figueiredo', 2, 0),
#  ('Chiyoko Ivanov', 'La llegada de el destino', 'Zara Teixeira', 2, 0),
#  ('Darius Vieira', 'La llave de la cueva', 'Mina Inácio', 4, 1),
#  ('Darius Xavier', 'El regreso de la aventura', 'Umar Bianchi', 2, 1),
#  ('Darius Xavier', 'La maldición del vampiro de la clave', 'Zara Oliveira', 2, 0),
#  ('Darius Xavier', 'La travesía de la pesadilla', 'Umar Bianchi', 2, 1),
#  ('Darya Cruz', 'El secreto de el lamento', 'Samir Wu', 2, 0),
#  ('Darya Cruz', 'La resurrección de el sacrificio', 'Valeria Correia', 1, 0),
#  ('Darya Lima', 'El eclipse de la caverna', 'Irina Vargas', 4, 0),
#  ('Darya Lima', 'El secreto de la muralla', 'Oscar Yilmaz', 3, 0),
#  ('Darya Lima', 'El tesoro de la luz', 'Zafar Watanabe', 1, 0),
#  ('Darya Martinez', 'El vuelo mágico de la selva', 'Genghis Yan', 4, 0),
#  ('Darya Martinez', 'La doncella de la bailarina', 'Zoya Joaquim', 3, 0),
#  ('Darya Nogueira', 'El tesoro escondido de el enigma', 'Umar Rodriguez', 2, 0),
#  ('Darya Nogueira', 'La escalada de la luz', 'Irina Vargas', 4, 0),
#  ('Elena Goncalves', 'El regreso de la aventura', 'Umar Bianchi', 2, 1),
#  ('Elena Goncalves', 'El resurgimiento de la cueva', 'Katarina Barros', 1, 0),
#  ('Elena Goncalves', 'La escalada de la leyenda', 'Mehmet Wu', 1, 0),
#  ('Elena Goncalves', 'La redención de la guerra', 'Parvati Zapata', 5, 0),
#  ('Elena Goncalves', 'La trampa de la puerta', 'Quintus Diniz', 2, 0),
#  ('Elena Goncalves', 'La travesía del océano de el renacer', 'Yasmin Kumar', 1, 0),
#  ('Elena Goncalves', 'La travesura de la guerra', 'Zara Teixeira', 2, 0),
#  ('Elena Pereira', 'El vuelo mágico de la montaña', 'Irina Rocha', 5, 0),
#  ('Elena Pereira', 'La búsqueda del tesoro de la bailarina', 'Omar Yilmaz', 1, 0),
#  ('Elena Pereira', 'La cripta de el desafío', 'Parvati Zapata', 5, 0),
#  ('Elena Pereira', 'La redención de la bailarina', 'Omar Sousa', 2, 1),
#  ('Elena Wu', 'El bosque encantado de la pesadilla', 'Javier Zapata', 2, 0),
#  ('Elena Wu', 'El camino hacia el laberinto', 'Giovanni Hidalgo', 2, 1),
#  ('Elena Wu', 'El prisionero de el laberinto', 'Quentin Abadi', 1, 0),
#  ('Elif Etxebarria', 'La búsqueda del tesoro de la reina', 'Valentina Gomes', 2, 0),
#  ('Elif Joaquim', 'El misterio de la verdad', 'Javier Teixeira', 1, 0),
#  ('Elif Joaquim', 'La invasión de el descubrimiento', 'Wang Lopes', 3, 0),
#  ('Elif Nunes', 'El canto de sirena de el abismo', 'Parvati Xu', 2, 0),
#  ('Elif Nunes', 'La metamorfosis de la aldea', 'Nina Henriquez', 3, 1),
#  ('Elif Nunes', 'La redención de la bailarina', 'Omar Sousa', 2, 1),
#  ('Elif Vargas', 'El eclipse de el laberinto', 'Wilhelmina Hidalgo', 1, 0),
#  ('Elif Vargas', 'La travesura de el peligro', 'Wilhelmina Ivanov', 2, 0),
#  ('Elif Xavier', 'El amanecer de la promesa', 'Isa Goncalves', 4, 0),
#  ('Elif Xavier', 'La senda de la bailarina', 'Mina Inácio', 4, 1),
#  ('Emiko Almeida', 'La misión de la magia', 'Orhan Wu', 5, 0),
#  ('Emiko Inácio', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Emiko Pereira', 'El cuento de hadas de el enigma', 'Bianca Abadi', 1, 0),
#  ('Emiko Pereira', 'El espejismo de el muro', 'Salim Velez', 2, 0),
#  ('Emiko Pereira', 'El hechizo de la montaña', 'Umar Rodriguez', 2, 0),
#  ('Emiko Pereira', 'La travesía de la pesadilla', 'Umar Bianchi', 2, 1),
#  ('Emiko Vieira', 'La cripta de el desafío', 'Parvati Zapata', 5, 0),
#  ('Emiko Xu', 'El amanecer de la leyenda', 'Akira Dutta', 1, 0),
#  ('Emiko Xu', 'El guardián de la prisión', 'Khaled Watanabe', 2, 0),
#  ('Emiko Yan', 'El espejismo de el muro', 'Salim Velez', 2, 0),
#  ('Emiko Yan', 'La odisea de el sueño', 'Xavier Bianchi', 3, 1),
#  ('Emiko Yan', 'La trampa de la amistad', 'Mikhail Fernandes', 3, 0),
#  ('Fabiana Diniz', 'El destino de la fortuna', 'Vivek Ivanov', 3, 0),
#  ('Fabiana Diniz', 'La fuente de el grito', 'Vivek Hidalgo', 1, 0),
#  ('Fabiana Diniz', 'La misión de la magia', 'Orhan Wu', 5, 0),
#  ('Fabiana Queiroz', 'El castillo de la noche', 'Hanako Santos', 2, 0),
#  ('Fabiana Velez', 'El descubrimiento de la pasión', 'Isa Goncalves', 4, 0),
#  ('Fabiana Velez', 'La canción de la espada', 'Zoya Joaquim', 3, 0),
#  ('Fabiana Velez', 'La tormenta de la bailarina', 'Oscar Yilmaz', 3, 0),
#  ('Fadhila Ferreira', 'El cuento de hadas de el enigma', 'Bianca Abadi', 1, 0),
#  ('Fadhila Ferreira', 'El guardián de la prisión', 'Khaled Watanabe', 2, 0),
#  ('Fadhila Ferreira', 'La travesura de la clave', 'Parvati Zapata', 5, 0),
#  ('Fadhila Gao', 'El espejismo de la traición', 'Xavier Diniz', 4, 0),
#  ('Fadhila Gao', 'La canción de el misterio', 'Giovanni Hidalgo', 2, 1),
#  ('Fadhila Oliveira', 'El pacto de la nube', 'Oscar Yilmaz', 3, 0),
#  ('Fadhila Oliveira', 'La metamorfosis de el guerrero', 'Salim Yamamoto', 3, 0),
#  ('Fadhila Ramos', 'El vuelo mágico de la montaña', 'Irina Rocha', 5, 0),
#  ('Fadhila Ramos', 'La llave de la paz', 'Quentin Xavier', 1, 0),
#  ('Fatemeh Jimenez', 'La fuga de el explorador', 'Salim Alvarez', 3, 0),
#  ('Fatemeh Jimenez', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Fatemeh Santana', 'El último viaje de la estrella', 'Mikhail Inácio', 2, 1),
#  ('Fatemeh Xia', 'La fuga de la trampa', 'Valeria Yilmaz', 2, 0),
#  ('Fatemeh Xia', 'La llave de el guerrero', 'Javier Almeida', 1, 0),
#  ('Genghis Cruz', 'El último viaje de la cárcel', 'Lakshmi Hernandez', 1, 0),
#  ('Genghis Cruz', 'La búsqueda del tesoro de la tormenta', 'Irina Vargas', 4, 0),
#  ('Genghis Mendes', 'El camino hacia el laberinto', 'Giovanni Hidalgo', 2, 1),
#  ('Genghis Mendes', 'El eclipse de la pesadilla', 'Nina Alvarez', 3, 1),
#  ('Genghis Mendes', 'El vuelo de la isla', 'Emiko Mendes', 3, 0),
#  ('Genghis Montenegro', 'El guardián de la puerta', 'Nina Henriquez', 3, 1),
#  ('Genghis Montenegro', 'El regreso de la verdad', 'Chiyoko Kumar', 4, 1),
#  ('Genghis Urbina', 'El secreto de la bruja', 'Gustavo Uchoa', 1, 1),
#  ('Genghis Urbina', 'El secreto oscuro de el trono', 'Irina Wu', 3, 0),
#  ('Genghis Urbina', 'La canción de el misterio', 'Giovanni Hidalgo', 2, 1),
#  ('Genghis Urbina', 'La escalada de la leyenda', 'Mehmet Wu', 1, 0),
#  ('Genghis Zhang', 'El lamento de la aventura', 'Xavier Gao', 2, 0),
#  ('Genghis Zhang', 'La canción de el mito', 'Orhan Wu', 5, 0),
#  ('Genghis Zhang', 'La maldición de el sapo', 'Mina Inácio', 4, 1),
#  ('Genghis Zhang', 'La misión de la magia', 'Orhan Wu', 5, 0),
#  ('Giovanni Borges', 'La búsqueda del tesoro de la bailarina', 'Omar Yilmaz', 1, 0),
#  ('Giovanni Borges', 'La trampa de la revelación', 'Han Hernandez', 5, 1),
#  ('Giovanni Goncalves', 'El arco iris de el descubrimiento', 'Yasmin Henriquez', 1, 0),
#  ('Giovanni Goncalves', 'La trampa de la magia', 'Aarav Esteves', 1, 0),
#  ('Giovanni Nunes', 'La rebelión de la oscuridad', 'Jin Ueno', 1, 0),
#  ('Giovanni Nunes', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Giovanni Zapata', 'El misterio de el amor', 'Dmitri Rodriguez', 1, 0),
#  ('Giovanni Zapata', 'La fuente de el grito', 'Vivek Hidalgo', 1, 0),
#  ('Han Sousa', 'El castillo de la clave', 'Samir Wu', 2, 0),
#  ('Han Sousa', 'La llave de la cueva', 'Mina Inácio', 4, 1),
#  ('Hanako Alvarez', 'El canto de sirena de la resistencia', 'Pilar Ueno', 2, 0),
#  ('Hanako Alvarez', 'El secreto de la paz', 'Wilhelmina Rocha', 4, 1),
#  ('Hanako Gomes', 'El secreto de el lamento', 'Samir Wu', 2, 0),
#  ('Hanako Gomes', 'La conquista de la traición', 'Alessandro Hernandez', 2, 0),
#  ('Hanako Urbina', 'El descubrimiento de el destino', 'Ursula Xia', 1, 1),
#  ('Hanako Urbina', 'El eclipse de la reina', 'Mikhail Iglesias', 1, 0),
#  ('Hanako Urbina', 'El resurgimiento de la senda', 'Bianca Pacheco', 3, 0),
#  ('Hanako Urbina', 'La llave de el viajero', 'Tatjana Figueiredo', 2, 0),
#  ('Hanako Urbina', 'La profecía de la luz', 'Wang Lopes', 3, 0),
#  ('Hanako Urbina', 'La senda de la escuela', 'Khaled Tan', 4, 0),
#  ('Hiroko Janssen', 'El cuento de hadas de el enigma', 'Bianca Abadi', 1, 0),
#  ('Hiroko Janssen', 'El lamento de la sonrisa', 'Hiroko Ivanov', 4, 0),
#  ('Hiroko Janssen', 'La tormenta de la montaña', 'Orhan Zhang', 4, 0),
#  ('Hiroko Pereira', 'El cuento de hadas de la montaña', 'Salim Velez', 2, 0),
#  ('Hiroko Pereira', 'El descubrimiento de la fortuna', 'Isa Goncalves', 4, 0),
#  ('Hiroko Pereira', 'El hechizo de la oscuridad', 'Oscar Rocha', 2, 1),
#  ('Hiroko Pereira', 'La trampa de la sombra', 'Theresa Almeida', 1, 0),
#  ('Ilya Ramos', 'El camino hacia la traición', 'Nadia Kawaguchi', 1, 0),
#  ('Ilya Ramos', 'El castillo de el río', 'Jasmin Iglesias', 2, 0),
#  ('Ilya Ramos', 'El hechizo de la montaña', 'Umar Rodriguez', 2, 0),
#  ('Ilya Ramos', 'El regreso de la luna', 'Emiko Mendes', 3, 0),
#  ('Ilya Ramos', 'La cripta de el león', 'Jasmin Iglesias', 2, 0),
#  ('Ilya Ramos', 'La travesura de el viaje', 'Emiko Fernandes', 1, 0),
#  ('Ilya Watanabe', 'El destino de la guerra', 'Irina Wu', 3, 0),
#  ('Ilya Watanabe', 'El hechizo de la montaña', 'Salim Mendes', 2, 0),
#  ('Ilya Watanabe', 'La escalada de la cascada', 'Samir Rodriguez', 2, 0),
#  ('Ilya Watanabe', 'La misión de la magia', 'Orhan Wu', 5, 0),
#  ('Ilya Watanabe', 'La odisea de la estrella', 'Javier Fernandes', 4, 0),
#  ('Ilya Watanabe', 'La trampa de la amistad', 'Mikhail Fernandes', 3, 0),
#  ('Irina Carvalho', 'El arco iris de el enigma', 'Xavier Gao', 2, 0),
#  ('Irina Carvalho', 'El vuelo de la isla', 'Emiko Mendes', 3, 0),
#  ('Irina Carvalho', 'La cripta de el león', 'Jasmin Iglesias', 2, 0),
#  ('Irina Carvalho', 'La resurrección de la corona', 'Xin Quintana', 2, 0),
#  ('Irina Oliveira', 'El arco iris de el enigma', 'Xavier Gao', 2, 0),
#  ('Irina Oliveira', 'El castillo de el río', 'Jasmin Iglesias', 2, 0),
#  ('Irina Oliveira', 'El despertar de la huida', 'Mikhail Inácio', 2, 1),
#  ('Irina Oliveira', 'La danza de la expedición', 'Samir Rodriguez', 2, 0),
#  ('Irina Wu', 'El guardián de la prisión', 'Khaled Watanabe', 2, 0),
#  ('Irina Wu', 'La estrella fugaz de la traición', 'Rashid Figueiredo', 4, 0),
#  ('Irina Wu', 'La llave de el guerrero', 'Javier Almeida', 1, 0),
#  ('Jasmin Alvarez', 'La travesura de el pacto', 'Orhan Zhang', 4, 0),
#  ('Jasmin Dutta', 'El enigma de el renacer', 'Lakshmi Sousa', 2, 0),
#  ('Jasmin Yamamoto', 'La estirpe de la selva', 'Wang Ueno', 2, 1),
#  ('Jasmin Yamamoto', 'La leyenda perdida de la traición', 'Yuri Dutta', 3, 2),
#  ('Javier Alvarez', 'La llegada de la perdición', 'Mina Vieira', 3, 0),
#  ('Javier Alvarez', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Javier Nguyen', 'El ritual de la caída', 'Han Hernandez', 5, 1),
#  ('Javier Nguyen', 'La fuga de el secreto', 'Hiroko Ivanov', 4, 0),
#  ('Javier Rodriguez', 'El misterio de la verdad', 'Javier Teixeira', 1, 0),
#  ('Javier Rodriguez', 'La cripta de la magia', 'Khaled Tan', 4, 0),
#  ('Javier Rodriguez', 'La fuga de la trampa', 'Valeria Yilmaz', 2, 0),
#  ('Javier Rodriguez', 'La misión de la magia', 'Orhan Wu', 5, 0),
#  ('Jin Xavier', 'La búsqueda del tesoro de el laberinto', 'Theresa Ramos', 1, 0),
#  ('Kamala Mendes', 'La tormenta de la bailarina', 'Oscar Yilmaz', 3, 0),
#  ('Katarina Esteves', 'El lamento de la sonrisa', 'Hiroko Ivanov', 4, 0),
#  ('Katarina Esteves', 'La redención de el vuelo', 'Natalia Cruz', 1, 0),
#  ('Katarina Xia', 'El canto de sirena de el sueño', 'Rashid Estevez', 2, 0),
#  ('Katarina Xia', 'El espejismo de la traición', 'Xavier Diniz', 4, 0),
#  ('Katarina Xia', 'El viajero de el árbol', 'Darius Bianchi', 1, 0),
#  ('Katarina Xia', 'La senda de la reina', 'Valeria Cruz', 2, 0),
#  ('Lakshmi Abadi', 'Las aventuras de el laberinto', 'Wilhelmina Ivanov', 2, 1),
#  ('Lakshmi Hidalgo', 'La búsqueda del tesoro de la guerra', 'Hanako Xia', 3, 3),
#  ('Leonardo Henriquez', 'El espejismo de el laberinto', 'Khaled Tan', 4, 0),
#  ('Leonardo Henriquez', 'La estirpe de la selva', 'Wang Ueno', 2, 1),
#  ('Leonardo Henriquez', 'La travesía del océano de la profecía', 'Mikhail Fernandes', 3, 0),
#  ('Leonardo Zapata', 'La canción de el misterio', 'Lakshmi Teixeira', 3, 0),
#  ('Leonardo Zapata', 'La invasión de la perdición', 'Tatiana Alvarez', 1, 0),
#  ('Leonardo Zhang', 'El cuento de hadas de el enigma', 'Bianca Abadi', 1, 0),
#  ('Leonardo Zhang', 'El hechizo de la montaña', 'Salim Mendes', 2, 0),
#  ('Leticia Correia', 'El despertar de la huida', 'Mikhail Inácio', 2, 1),
#  ('Leticia Correia', 'El despertar de la ley', 'Katarina Zambrano', 3, 0),
#  ('Leticia Correia', 'El guardián de la expedición', 'Fatemeh Kumar', 1, 0),
#  ('Leticia Hidalgo', 'El laberinto de la prisión', 'Wilhelmina Rocha', 4, 1),
#  ('Leticia Hidalgo', 'La canción de el misterio', 'Giovanni Hidalgo', 2, 1),
#  ('Leticia Joaquim', 'El espejismo de la traición', 'Xavier Diniz', 4, 0),
#  ('Leticia Joaquim', 'La búsqueda del tesoro de el laberinto', 'Theresa Ramos', 1, 0),
#  ('Leticia Joaquim', 'La búsqueda del tesoro de la guerra', 'Hanako Xia', 3, 3),
#  ('Mehmet Iglesias', 'La trampa de la revelación', 'Han Hernandez', 5, 1),
#  ('Mehmet Iglesias', 'La travesura de el fuego', 'Lakshmi Teixeira', 3, 0),
#  ('Mehmet Iglesias', 'Las aventuras de la esperanza', 'Hanako Xia', 3, 3),
#  ('Mehmet Santana', 'El ritual de la caída', 'Han Hernandez', 5, 1),
#  ('Mehmet Zapata', 'El espejismo de el muro', 'Salim Velez', 2, 0),
#  ('Mehmet Zapata', 'El tesoro escondido de el puente', 'Elena Kumar', 1, 0),
#  ('Mehmet Zapata', 'La maldición del vampiro de el perdón', 'Wilhelmina Rocha', 4, 1),
#  ('Mehmet Zapata', 'La tormenta de la montaña', 'Orhan Zhang', 4, 0),
#  ('Mikhail Olivares', 'El descubrimiento de la pasión', 'Isa Goncalves', 4, 0),
#  ('Mina Joaquim', 'La trampa de la amistad', 'Mikhail Fernandes', 3, 0),
#  ('Natalia Dutta', 'El descubrimiento de el mito', 'Vivek Joaquim', 1, 0),
#  ('Natalia Dutta', 'El tesoro escondido de el enigma', 'Umar Rodriguez', 2, 0),
#  ('Natalia Dutta', 'La canción de la cueva', 'Mikhail Kumar', 2, 0),
#  ('Natalia Dutta', 'La escalada de la luz', 'Irina Vargas', 4, 0),
#  ('Natalia Dutta', 'La estirpe de el unicornio', 'Mikhail Santos', 3, 0),
#  ('Natalia Goncalves', 'La tormenta de el océano', 'Dmitri Queiroz', 1, 0),
#  ('Natalia Sousa', 'El caballero de la caída', 'Wilhelmina Ivanov', 2, 0),
#  ('Natalia Sousa', 'La búsqueda del tesoro de la travesía', 'Hanako Santos', 2, 0),
#  ('Natalia Sousa', 'La canción de la espada', 'Zoya Joaquim', 3, 0),
#  ('Natalia Sousa', 'La metamorfosis de el guerrero', 'Salim Yamamoto', 3, 0),
#  ('Natalia Sousa', 'La tormenta de el laberinto', 'Salim Sousa', 1, 0),
#  ('Natalia Sousa', 'La travesía del océano de el secreto', 'Mina Vieira', 3, 0),
#  ('Natalia Sousa', 'La travesía del océano de la isla', 'Darya Nunes', 2, 0),
#  ('Natalia Teles', 'El arco iris de el enigma', 'Xavier Gao', 2, 0),
#  ('Natalia Teles', 'El destino de la pasión', 'Katarina Zambrano', 3, 0),
#  ('Natalia Teles', 'El laberinto de la prisión', 'Wilhelmina Rocha', 4, 1),
#  ('Natalia Teles', 'El regreso de la verdad', 'Chiyoko Kumar', 4, 1),
#  ('Natalia Teles', 'El resurgimiento de la senda', 'Bianca Pacheco', 3, 0),
#  ('Natalia Teles', 'El vuelo de la isla', 'Emiko Mendes', 3, 0),
#  ('Natalia Teles', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Natalia Teles', 'Las aventuras de el puente', 'Salim Mendes', 2, 0),
#  ('Nina Watanabe', 'El amanecer de la promesa', 'Isa Goncalves', 4, 0),
#  ('Nina Watanabe', 'El canto de sirena de la resistencia', 'Pilar Ueno', 2, 0),
#  ('Nina Watanabe', 'La trampa de la puerta', 'Quintus Diniz', 2, 0),
#  ('Orhan Dutta', 'El castillo de la noche', 'Hanako Santos', 2, 0),
#  ('Orhan Dutta', 'El destino de la luz', 'Lakshmi Teixeira', 3, 0),
#  ('Orhan Dutta', 'La redención de la bailarina', 'Omar Sousa', 2, 1),
#  ('Orhan Dutta', 'La travesura de la clave', 'Parvati Zapata', 5, 0),
#  ('Orhan Inácio', 'El descubrimiento de la paz', 'Xin Quintana', 2, 0),
#  ('Orhan Inácio', 'El grito de el horizonte', 'Xavier Diniz', 4, 0),
#  ('Orhan Inácio', 'La batalla de el fuego', 'Javier Abadi', 2, 1),
#  ('Orhan Qian', 'El pacto de la despedida', 'Mina Montenegro', 2, 0),
#  ('Orhan Qian', 'El ritual de la caída', 'Han Hernandez', 5, 1),
#  ('Orhan Qian', 'La rebelión de la oscuridad', 'Jin Ueno', 1, 0),
#  ('Oscar Pereira', 'El amanecer de la gárgola', 'Wilhelmina Ivanov', 2, 1),
#  ('Oscar Pereira', 'La tormenta de la revelación', 'Xavier Diniz', 4, 0),
#  ('Oscar Pereira', 'La travesía del océano de el renacer', 'Yasmin Kumar', 1, 0),
#  ('Oscar Teles', 'El amanecer de el guardián', 'Nina Alvarez', 3, 1),
#  ('Oscar Teles', 'El caballero de la caída', 'Wilhelmina Ivanov', 2, 0),
#  ('Parvati Iglesias', 'El despertar de el muro', 'Emiko Mendes', 3, 0),
#  ('Parvati Iglesias', 'El laberinto de la prisión', 'Wilhelmina Rocha', 4, 1),
#  ('Parvati Iglesias', 'La invasión de la isla', 'Javier Fernandes', 4, 0),
#  ('Parvati Ortega', 'El misterio de la verdad', 'Javier Teixeira', 1, 0),
#  ('Parvati Ortega', 'El tesoro escondido de el puente', 'Elena Kumar', 1, 0),
#  ('Parvati Ortega', 'La batalla de el abismo', 'Khaled Tan', 4, 0),
#  ('Parvati Ueno', 'La estirpe de la selva', 'Wang Ueno', 2, 1),
#  ('Parvati Ueno', 'La resurrección de la estrella', 'Bianca Pacheco', 3, 0),
#  ('Parvati Urbina', 'El ritual de la aventura', 'Jasmin Goncalves', 3, 1),
#  ('Patricia Duarte', 'La cripta de la magia', 'Khaled Tan', 4, 0),
#  ('Pilar Estevez', 'El eclipse de la pesadilla', 'Nina Alvarez', 3, 1),
#  ('Pilar Estevez', 'La maldición del vampiro de el perdón', 'Wilhelmina Rocha', 4, 1),
#  ('Pilar Estevez', 'Las aventuras de el muro', 'Pilar Pereira', 1, 1),
#  ('Qiu Rodriguez', 'El ritual de la luz', 'Omar Santos', 1, 0),
#  ('Qiu Rodriguez', 'La estrella fugaz de el fuego', 'Wan Iglesias', 3, 0),
#  ('Quentin Carvalho', 'El guardián de la expedición', 'Fatemeh Kumar', 1, 0),
#  ('Quentin Carvalho', 'El viaje de el faro', 'Vivek Ivanov', 3, 0),
#  ('Quentin Carvalho', 'La cripta de la esperanza', 'Hiroko Ivanov', 4, 0),
#  ('Quentin Cruz', 'El despertar de el muro', 'Emiko Mendes', 3, 0),
#  ('Quentin Cruz', 'El enigma de la montaña', 'Vivek Lopes', 2, 0),
#  ('Quentin Cruz', 'La travesura de el viaje', 'Emiko Fernandes', 1, 0),
#  ('Quentin Santos', 'El vuelo mágico de la montaña', 'Irina Rocha', 5, 0),
#  ('Quentin Santos', 'La senda de el sacrificio', 'Mikhail Hidalgo', 2, 1),
#  ('Quintus Teles', 'El regreso de la aventura', 'Umar Bianchi', 2, 1),
#  ('Quintus Teles', 'El último viaje de la estrella', 'Mikhail Inácio', 2, 1),
#  ('Rania Ivanov', 'El regreso de la luna', 'Emiko Mendes', 3, 0),
#  ('Rania Ivanov', 'El secreto de el lamento', 'Samir Wu', 2, 0),
#  ('Rania Ivanov', 'La travesía de el descubrimiento', 'Salim Alvarez', 3, 0),
#  ('Rashid Kawaguchi', 'El ritual de la corona', 'Orhan Zhang', 4, 0),
#  ('Rashid Kawaguchi', 'La travesía sin retorno de la mariposa', 'Hanako Bianchi', 1, 0),
#  ('Rashid Qian', 'El canto de sirena de el sueño', 'Rashid Estevez', 2, 0),
#  ('Rashid Uchoa', 'El eclipse de el rey', 'Fadhila Pereira', 1, 0),
#  ('Rosa Duarte', 'El espejismo de el sol', 'Aarav Dutta', 2, 0),
#  ('Rosa Jimenez', 'El caballero de el tesoro', 'Mina Montenegro', 2, 0),
#  ('Rosa Jimenez', 'El camino hacia la travesía', 'Mikhail Kumar', 2, 0),
#  ('Rosa Jimenez', 'La búsqueda del tesoro de el laberinto', 'Theresa Ramos', 1, 0),
#  ('Rosa Mendes', 'El bosque encantado de la luz', 'Darius Santos', 1, 0),
#  ('Rosa Mendes', 'El lamento de la sonrisa', 'Hiroko Ivanov', 4, 0),
#  ('Rosa Mendes', 'La senda de la escuela', 'Khaled Tan', 4, 0),
#  ('Rosa Nogueira', 'El regreso de la cascada', 'Xavier Diniz', 4, 0),
#  ('Sakura Dutta', 'La búsqueda del tesoro de el rey', 'Darius Vargas', 1, 0),
#  ('Sakura Dutta', 'La conquista de la traición', 'Alessandro Hernandez', 2, 0),
#  ('Sakura Dutta', 'La estirpe de la libertad', 'Chiyoko Kumar', 4, 1),
#  ('Sakura Figueiredo', 'El lamento de la aventura', 'Xavier Gao', 2, 0),
#  ('Sakura Figueiredo', 'La fuente de el renacimiento', 'Chiyoko Kumar', 4, 1),
#  ('Sakura Joaquim', 'El último viaje de la heroína', 'Javier Velez', 3, 1),
#  ('Sakura Petrov', 'El grito de el horizonte', 'Xavier Diniz', 4, 0),
#  ('Sakura Petrov', 'La búsqueda de la caída', 'Emiko Ortega', 2, 0),
#  ('Sakura Petrov', 'La búsqueda del tesoro de la guerra', 'Hanako Xia', 3, 3),
#  ('Sakura Petrov', 'La llegada de la espada mágica', 'Omar Sousa', 2, 1),
#  ('Samir Jimenez', 'El ritual de la aventura', 'Jasmin Goncalves', 3, 1),
#  ('Tatiana Cruz', 'El eclipse de la caverna', 'Irina Vargas', 4, 0),
#  ('Tatiana Lopes', 'La estirpe de la libertad', 'Chiyoko Kumar', 4, 1),
#  ('Tatiana Lopes', 'La llave de el guerrero', 'Javier Almeida', 1, 0),
#  ('Tatjana Queiroz', 'La batalla de el unicornio', 'Han Hernandez', 5, 1),
#  ('Tatjana Queiroz', 'La metamorfosis de el guerrero', 'Salim Yamamoto', 3, 0),
#  ('Tatjana Queiroz', 'La metamorfosis de el viaje', 'Xavier Barros', 2, 0),
#  ('Umar Oliveira', 'El enigma de la montaña', 'Vivek Lopes', 2, 0),
#  ('Umar Oliveira', 'La maldición del vampiro de el perdón', 'Wilhelmina Rocha', 4, 1),
#  ('Umar Vargas', 'El arco iris de el enigma', 'Xavier Gao', 2, 0),
#  ('Umar Vargas', 'Las aventuras de el laberinto', 'Wilhelmina Ivanov', 2, 1),
#  ('Ursula Cruz', 'El regreso de la cascada', 'Xavier Diniz', 4, 0),
#  ('Ursula Lima', 'La canción de la espada', 'Zoya Joaquim', 3, 0),
#  ('Ursula Lima', 'Las aventuras de el laberinto', 'Wilhelmina Ivanov', 2, 1),
#  ('Ursula Lopes', 'El tesoro escondido de el enigma', 'Umar Rodriguez', 2, 0),
#  ('Valentina Gao', 'El canto de sirena de el abismo', 'Parvati Xu', 2, 0),
#  ('Valentina Gao', 'La llave de el guerrero', 'Javier Almeida', 1, 0),
#  ('Valentina Gao', 'La redención de la bailarina', 'Omar Sousa', 2, 1),
#  ('Valentina Hidalgo', 'El hechizo de la montaña', 'Umar Rodriguez', 2, 0),
#  ('Valentina Hidalgo', 'El vuelo mágico de la montaña', 'Irina Rocha', 5, 0),
#  ('Valentina Hidalgo', 'La estirpe de la oscuridad', 'Rashid Figueiredo', 4, 0),
#  ('Valentina Hidalgo', 'La travesía sin retorno de el monstruo', 'Mikhail Fernandes', 3, 0),
#  ('Valentina Watanabe', 'La fortuna de la bruja', 'Mikhail Santos', 3, 0),
#  ('Valentina Yilmaz', 'La senda de la esperanza', 'Genghis Yan', 4, 0),
#  ('Valentina Zambrano', 'El eclipse de el rey', 'Fadhila Pereira', 1, 0),
#  ('Valentina Zambrano', 'El viaje de el faro', 'Vivek Ivanov', 3, 0),
#  ('Valeria Cruz', 'El camino hacia la traición', 'Nadia Kawaguchi', 1, 0),
#  ('Valeria Cruz', 'La llave de la tierra', 'Wan Iglesias', 3, 0),
#  ('Vivek Ferreira', 'La búsqueda del tesoro de la reina', 'Valentina Gomes', 2, 0),
#  ('Wan Urbina', 'La llave de el viajero', 'Tatjana Figueiredo', 2, 0),
#  ('Wang Ferreira', 'El caballero de el tesoro', 'Mina Montenegro', 2, 0),
#  ('Wang Ferreira', 'El camino hacia el laberinto', 'Giovanni Hidalgo', 2, 1),
#  ('Wang Ferreira', 'La búsqueda del tesoro de la travesía', 'Hanako Santos', 2, 0),
#  ('Wang Ferreira', 'La llegada de el renacer', 'Valeria Yilmaz', 2, 0),
#  ('Wang Yan', 'El amanecer de la gárgola', 'Wilhelmina Ivanov', 2, 1),
#  ('Wang Yan', 'El castillo de la noche', 'Hanako Santos', 2, 0),
#  ('Wang Yan', 'La estrella fugaz de la aventura', 'Kamala Lima', 2, 0),
#  ('Wang Yan', 'La tormenta de la bailarina', 'Oscar Yilmaz', 3, 0),
#  ('Wilhelmina Gao', 'La batalla de el fuego', 'Javier Abadi', 2, 1),
#  ('Wilhelmina Gao', 'La llave de la tierra', 'Wan Iglesias', 3, 0),
#  ('Wilhelmina Gao', 'La tormenta de la montaña', 'Orhan Zhang', 4, 0),
#  ('Wilhelmina Gao', 'La travesía sin retorno de la mariposa', 'Hanako Bianchi', 1, 0),
#  ('Xavier Olivares', 'El descubrimiento de el mito', 'Vivek Joaquim', 1, 0),
#  ('Xavier Olivares', 'La fuente de el renacimiento', 'Chiyoko Kumar', 4, 1),
#  ('Xavier Olivares', 'La odisea de el sueño', 'Xavier Bianchi', 3, 1),
#  ('Xavier Olivares', 'La redención de el muro', 'Han Teixeira', 1, 0),
#  ('Xavier Olivares', 'La trampa de la amistad', 'Mikhail Fernandes', 3, 0),
#  ('Xavier Xia', 'El canto de sirena de la resistencia', 'Pilar Ueno', 2, 0),
#  ('Xavier Xia', 'Las aventuras de el laberinto', 'Wilhelmina Ivanov', 2, 1),
#  ('Ximena Hernandez', 'El arco iris de el enigma', 'Xavier Gao', 2, 0),
#  ('Ximena Hernandez', 'El castillo de el río', 'Jasmin Iglesias', 2, 0),
#  ('Ximena Jimenez', 'El pacto de la nube', 'Oscar Yilmaz', 3, 0),
#  ('Ximena Jimenez', 'La búsqueda del tesoro de el laberinto', 'Theresa Ramos', 1, 0),
#  ('Ximena Jimenez', 'La cripta de la magia', 'Khaled Tan', 4, 0),
#  ('Ximena Jimenez', 'La travesía sin retorno de el monstruo', 'Mikhail Fernandes', 3, 0),
#  ('Ximena Queiroz', 'El descubrimiento de la paz', 'Xin Quintana', 2, 0),
#  ('Ximena Queiroz', 'El lamento de la aventura', 'Xavier Gao', 2, 0),
#  ('Ximena Queiroz', 'La senda de la bailarina', 'Mina Inácio', 4, 1),
#  ('Ximena Tan', 'El hechizo de la desgracia', 'Nina Henriquez', 3, 1),
#  ('Ximena Tan', 'La travesía de el descubrimiento', 'Salim Alvarez', 3, 0),
#  ('Xin Borges', 'El tesoro escondido de la clave', 'Oscar Rocha', 2, 1),
#  ('Xin Borges', 'El último viaje de la aventura', 'Genghis Yan', 4, 0),
#  ('Xin Borges', 'La fuga de el explorador', 'Salim Alvarez', 3, 0),
#  ('Xin Jimenez', 'La búsqueda del tesoro de la guerra', 'Hanako Xia', 3, 3),
#  ('Xin Jimenez', 'La tormenta de la revelación', 'Xavier Diniz', 4, 0),
#  ('Xin Rodriguez', 'El descubrimiento de la paz', 'Xin Quintana', 2, 0),
#  ('Xin Rodriguez', 'El espejismo de la traición', 'Xavier Diniz', 4, 0),
#  ('Xin Rodriguez', 'El hechizo de la princesa', 'Quintus Diniz', 2, 0),
#  ('Xin Rodriguez', 'La búsqueda del tesoro de el laberinto', 'Theresa Ramos', 1, 0),
#  ('Yasmin Correia', 'La búsqueda del tesoro de la bailarina', 'Omar Yilmaz', 1, 0),
#  ('Yasmin Correia', 'La fortuna de la montaña', 'Zafar Diniz', 1, 0),
#  ('Yasmin Correia', 'La travesía del océano de la gárgola', 'Orhan Wu', 5, 0),
#  ('Yasmin Queiroz', 'El eclipse de el laberinto', 'Wilhelmina Hidalgo', 1, 0),
#  ('Yasmin Queiroz', 'El eclipse de la pesadilla', 'Nina Alvarez', 3, 1),
#  ('Yasmin Queiroz', 'El secreto oscuro de el trono', 'Irina Wu', 3, 0),
#  ('Yasmin Queiroz', 'El vuelo de el viaje', 'Jasmin Goncalves', 3, 1),
#  ('Yasmin Queiroz', 'La leyenda de el sueño', 'Umberto Ferreira', 1, 0),
#  ('Yusef Hidalgo', 'La batalla de el fuego', 'Javier Abadi', 2, 1),
#  ('Yusef Hidalgo', 'La invasión de la perdición', 'Tatiana Alvarez', 1, 0),
#  ('Yusef Hidalgo', 'La travesía del océano de la gárgola', 'Orhan Wu', 5, 0),
#  ('Yusef Kumar', 'El tesoro escondido de el horizonte', 'Fabiana Gomes', 1, 0),
#  ('Yusef Urbina', 'La llave de la paz', 'Quentin Xavier', 1, 0),
#  ('Zafar Gao', 'El ritual de la libertad', 'Javier Velez', 3, 1),
#  ('Zafar Gao', 'La fuga de el secreto', 'Hiroko Ivanov', 4, 0),
#  ('Zafar Gao', 'La metamorfosis de el viaje', 'Xavier Barros', 2, 0),
#  ('Zafar Gao', 'La travesía del océano de el secreto', 'Mina Vieira', 3, 0),
#  ('Zafar Lopez', 'El eclipse de la pesadilla', 'Nina Alvarez', 3, 1),
#  ('Zafar Lopez', 'La escalada de la luz', 'Irina Vargas', 4, 0),
#  ('Zafar Olivares', 'El cuento de hadas de la montaña', 'Salim Velez', 2, 0),
#  ('Zafar Olivares', 'El hechizo de la princesa', 'Quintus Diniz', 2, 0),
#  ('Zafar Olivares', 'El tesoro de el león', 'Xavier Bianchi', 3, 1),
#  ('Zara Gao', 'El guardián de la puerta', 'Nina Henriquez', 3, 1),
#  ('Zara Gao', 'La invasión de la esperanza', 'Tatiana Santana', 3, 0),
#  ('Zara Pereira', 'El pacto de la corona', 'Bianca Pacheco', 3, 0),
#  ('Zara Pereira', 'El refugio de la espada mágica', 'Irina Rocha', 5, 0),
#  ('Zara Pereira', 'La travesura de el fuego', 'Lakshmi Teixeira', 3, 0),
#  ('Zoya Mendes', 'La búsqueda del tesoro de la bailarina', 'Omar Yilmaz', 1, 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
